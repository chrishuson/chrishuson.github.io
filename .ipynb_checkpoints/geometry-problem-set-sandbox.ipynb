# %% [markdown]
# # Header code

# %%
import os
import sys

import pandas as pd
#pd.set_option('display.max_colwidth', None) # Wrap text in cells to show all of large fields
import numpy as np
#import plotly_express as px
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook --for interactive graphics

os.getcwd()
# Out:
# '/Users/chris/GitHub/chrishuson.github.io/.ipynb_checkpoints'

# %%
import os
import sys

os.getcwd()
# Out:
# '/Users/chris/GitHub/chrishuson.github.io/.ipynb_checkpoints'

# %% [markdown]
# # Pure math text examples
# 1. A cone has a volume of $108\pi$ and a base diameter of $12$. What is the
# height of the cone?
#
# 1. The endpoints of directed line segment $PQ$ have coordinates of
# $P(-7,-5)$ and $Q(5,3)$. What are the coordinates of point $A$, on $\overline{PQ}$,
# that divide $\overline{PQ}$ into a ratio of $1:3$?

# %% [markdown]
# # Multiple choice
# 1. Jaden is comparing two cones. The radius of the base of cone $A$ is
# twice as large as the radius of the base of cone B. The height of cone
# B is twice the height of cone A. The volume of cone A is
#     1. twice the volume of cone $B$
#     1. four times the volume of cone $B$
#     1. equal to the volume of cone $B$
#     1. equal to half the volume of cone $B$
#
# 1. A regular hexagon is rotated about its center. Which degree measure will carry the regular hexagon onto itself?
#     1. $45^\circ$
#     1. $90^\circ$
#     1. $120^\circ$
#     1. $135^\circ$

# %% [markdown]
# # Images
#
# [picture png file](https://github.com/chrishuson/course-files/blob/master/Geom2021/Slides/5-9reflect%2Btranslate.png)
# ![5-9reflect+translate.png](data:image/png;base64,...)

# %% [markdown]
# [link text](https://raw.githubusercontent.com/chrishuson/course-files/master/Geom2023/graphics/06triangle.png)

# %% [markdown]
# # Cases
# $f(n) =
#   \begin{cases}
#     n/2       & \quad \text{if } n \text{ is even}\\
#     -(n+1)/2  & \quad \text{if } n \text{ is odd}
#   \end{cases}$
